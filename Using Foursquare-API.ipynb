# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jalma\Documents\Anaconda3\Anaconda3_Files
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
#
# geopy-1.22.0         | 63 KB     |            |   0%
# geopy-1.22.0         | 63 KB     | ##5        |  26%
# geopy-1.22.0         | 63 KB     | ########## | 100%
#
# geographiclib-1.50   | 34 KB     |            |   0%
# geographiclib-1.50   | 34 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jalma\Documents\Anaconda3\Anaconda3_Files
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         861 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# altair-4.1.0         | 614 KB    |            |   0%
# altair-4.1.0         | 614 KB    | 2          |   3%
# altair-4.1.0         | 614 KB    | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# branca-0.4.1         | 26 KB     |            |   0%
# branca-0.4.1         | 26 KB     | ########## | 100%
#
# certifi-2019.11.28   | 148 KB    |            |   0%
# certifi-2019.11.28   | 148 KB    | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '3LOX1XCTNAEPXKSWU1NEMIZB21FN4YVONAVZSSUFFQS2BR3K' # your Foursquare ID
CLIENT_SECRET = 'JIMJSWLBD5UVHYYVUX34PBRAFB51G22ADXPDBJYNYN2NBDC0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3LOX1XCTNAEPXKSWU1NEMIZB21FN4YVONAVZSSUFFQS2BR3K
# CLIENT_SECRET:JIMJSWLBD5UVHYYVUX34PBRAFB51G22ADXPDBJYNYN2NBDC0

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent") #creates a instance of useragent, define user_agent
location = geolocator.geocode(address) #geolocater intance 
latitude = location.latitude #creates an instance for location as latitude
longitude = location.longitude #creates an instance for location as longitude
print(latitude, longitude) #prints the address input and outputs a a
# Out:
# 40.7151482 -74.0156573

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %%
search_query = 'Italian'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3LOX1XCTNAEPXKSWU1NEMIZB21FN4YVONAVZSSUFFQS2BR3K&client_secret=JIMJSWLBD5UVHYYVUX34PBRAFB51G22ADXPDBJYNYN2NBDC0&ll=40.715337,-74.008848&v=20180604&query=Italian&radius=5000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec74c7f9fcb92002955e0cd'},
#  'response': {'venues': [{'id': '4a4560a7f964a5201aa81fe3',
#     'name': "Harry's Italian Pizza Bar",
#     'location': {'address': '2 Gold St',
#      'crossStreet': 'at Maiden Ln.',
#      'lat': 40.7076335455641,
#      'lng': -74.00699585960496,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7076335455641,
#        'lng': -74.00699585960496}],
#      'distance': 871,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 Gold St (at Maiden Ln.)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '77559825'},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4b9d4c67f964a5206ca136e3',
#     'name': 'Italian American Museum Of New York',
#     'location': {'address': '155 Mulberry St',
#      'crossStreet': 'at Grand St',
#      'lat': 40.71919065572268,
#      'lng': -73.99737599769244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71919065572268,
#        'lng': -73.99737599769244}],
#      'distance': 1058,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['155 Mulberry St (at Grand St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '66342615'},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4a74a36af964a520fede1fe3',
#     'name': "Faicco's Italian Specialties",
#     'location': {'address': '260 Bleecker St',
#      'crossStreet': 'at Cornelia St',
#      'lat': 40.73111661087598,
#      'lng': -74.0030425786972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73111661087598,
#        'lng': -74.0030425786972}],
#      'distance': 1823,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['260 Bleecker St (at Cornelia St)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520f4e41ee3',
#     'name': 'Ecco',
#     'location': {'address': '124 Chambers St',
#      'crossStreet': 'btwn Church St & W Broadway',
#      'lat': 40.71533713859952,
#      'lng': -74.00884766217825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71533713859952,
#        'lng': -74.00884766217825},
#       {'label': 'entrance', 'lat': 40.715202, 'lng': -74.008779}],
#      'distance': 0,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['124 Chambers St (btwn Church St & W Broadway)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4f3232e219836c91c7bfde94',
#     'name': 'Conca Cucina Italian Restaurant',
#     'location': {'address': '63 W Broadway',
#      'lat': 40.714484000000006,
#      'lng': -74.00980600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714484000000006,
#        'lng': -74.00980600000001}],
#      'distance': 124,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['63 W Broadway',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4fa862b3e4b0ebff2f749f06',
#     'name': "Harry's Italian Pizza Bar",
#     'location': {'address': '225 Murray St',
#      'lat': 40.71521779064671,
#      'lng': -74.01473940209351,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71521779064671,
#        'lng': -74.01473940209351},
#       {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}],
#      'distance': 497,
#      'postalCode': '10282',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['225 Murray St',
#       'New York, NY 10282',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '58dd8ac3a8b75966fda9a547',
#     'name': 'Tableside Italian Cook Shoppe',
#     'location': {'address': '345 E 6th St',
#      'crossStreet': '1st and 2nd Ave',
#      'lat': 40.726556174383305,
#      'lng': -73.98651414092868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726556174383305,
#        'lng': -73.98651414092868}],
#      'distance': 2260,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['345 E 6th St (1st and 2nd Ave)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1700675',
#      'url': 'https://www.seamless.com/menu/tableside-italian-cook-shoppe-345-e-6th-st-new-york/1700675?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1700675',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '427907002'},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4e4c4e62bd413c4cc6686059',
#     'name': "Carmela's Italian Specialties",
#     'location': {'address': '30 Water St',
#      'lat': 40.71981178398971,
#      'lng': -74.03504130880152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71981178398971,
#        'lng': -74.03504130880152}],
#      'distance': 2265,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['30 Water St',
#       'New York, NJ 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '528bf16711d2b7722da6b51c',
#     'name': 'Pisillo Italian Panini',
#     'location': {'address': '97 Nassau St',
#      'crossStreet': 'at Ann St',
#      'lat': 40.710530084460785,
#      'lng': -74.00752571804911,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710530084460785,
#        'lng': -74.00752571804911}],
#      'distance': 546,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['97 Nassau St (at Ann St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '286355',
#      'url': 'https://www.seamless.com/menu/pisillo-97-nassau-st-new-york/286355?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=286355',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '105457747'},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4cf7d538dc40a35d26894f54',
#     'name': 'Italian Culinary Academy',
#     'location': {'address': '462 Broadway',
#      'crossStreet': 'Grand St.',
#      'lat': 40.71883786954379,
#      'lng': -73.99783518413365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71883786954379,
#        'lng': -73.99783518413365}],
#      'distance': 1007,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['462 Broadway (Grand St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d199941735',
#       'name': 'College Arts Building',
#       'pluralName': 'College Arts Buildings',
#       'shortName': 'Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '51a63ef7498e9eedb94e0c5f',
#     'name': 'Italian Food Center',
#     'location': {'address': '161 Mulberry St',
#      'crossStreet': 'at Grand St.',
#      'lat': 40.719589,
#      'lng': -73.997339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.719589,
#        'lng': -73.997339},
#       {'label': 'entrance', 'lat': 40.719579, 'lng': -73.997296}],
#      'distance': 1080,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['161 Mulberry St (at Grand St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4e4c4d28bd413c4cc66857a5',
#     'name': "Caruso's Italian Restaurant",
#     'location': {'address': '42 Broadway',
#      'lat': 40.710509099999996,
#      'lng': -74.00827615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.710509099999996,
#        'lng': -74.00827615}],
#      'distance': 539,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['42 Broadway',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '5c893ef0d8096e0039e7363b',
#     'name': 'Pisillo Italian Panini',
#     'location': {'address': '124 W 25th St',
#      'crossStreet': 'btwn 6th & 7th Ave',
#      'lat': 40.744566,
#      'lng': -73.992868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744566,
#        'lng': -73.992868},
#       {'label': 'entrance', 'lat': 40.744568, 'lng': -73.992984}],
#      'distance': 3521,
#      'postalCode': '10001',
#      'cc': 'US',
#      'neighborhood': 'Chelsea',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['124 W 25th St (btwn 6th & 7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1108715',
#      'url': 'https://www.seamless.com/menu/pisillo-124-w-25th-st-new-york/1108715?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1108715',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '5400c682498e3831aaada9fc',
#     'name': "Alex's Italian Restaurant & Brick Oven Pizza",
#     'location': {'address': '346 Grove St',
#      'lat': 40.72058470693942,
#      'lng': -74.04275196874856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72058470693942,
#        'lng': -74.04275196874856}],
#      'distance': 2919,
#      'postalCode': '07302',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['346 Grove St',
#       'Jersey City, NJ 07302',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '294871',
#      'url': 'https://www.grubhub.com/restaurant/alex-pizza-and-italian-restaurant-346-grove-st-jersey-city/294871?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294871',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4f3feae2e4b0ac9416a72118',
#     'name': 'Benvenuti Italian Specialties',
#     'location': {'address': '235 S End Ave',
#      'lat': 40.70968105555279,
#      'lng': -74.01652043988257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70968105555279,
#        'lng': -74.01652043988257}],
#      'distance': 903,
#      'postalCode': '10280',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['235 S End Ave',
#       'New York, NY 10280',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '588a4316326c5a4b60559f17',
#     'name': 'Pisillo Italian Cafe',
#     'location': {'lat': 40.71049280792626,
#      'lng': -74.00754611675153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71049280792626,
#        'lng': -74.00754611675153}],
#      'distance': 550,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '50de11fde4b0a94f4e13d7cd',
#     'name': 'Italian Bakery 160 Prince',
#     'location': {'lat': 40.725955,
#      'lng': -74.001161,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.725955,
#        'lng': -74.001161}],
#      'distance': 1348,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10012', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4b269f5af964a520817e24e3',
#     'name': "Losurdo Brothers / Tony's Italian Bakery & Deli",
#     'location': {'address': '410 2nd St',
#      'crossStreet': 'btw Grand St & Adams St',
#      'lat': 40.74012586093679,
#      'lng': -74.0369639338283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74012586093679,
#        'lng': -74.0369639338283}],
#      'distance': 3638,
#      'postalCode': '07030',
#      'cc': 'US',
#      'city': 'Hoboken',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['410 2nd St (btw Grand St & Adams St)',
#       'Hoboken, NJ 07030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4c3b8244def90f478f0ffe2d',
#     'name': 'Barber Italian Shop',
#     'location': {'address': '120 Broadway',
#      'crossStreet': 'btw Cedar & Pine',
#      'lat': 40.70796968555732,
#      'lng': -74.00994920143108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70796968555732,
#        'lng': -74.00994920143108}],
#      'distance': 825,
#      'postalCode': '10271',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Broadway (btw Cedar & Pine)',
#       'New York, NY 10271',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4bd78b4809ecb7138732477c',
#     'name': 'Italian Rifle Club',
#     'location': {'lat': 40.72858856840826,
#      'lng': -74.00174320053318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72858856840826,
#        'lng': -74.00174320053318}],
#      'distance': 1592,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10012', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4d97923e61a3a1cdb92ab942',
#     'name': 'Little Italian Rooftop',
#     'location': {'address': '182 Hester St',
#      'lat': 40.71823673,
#      'lng': -73.99806087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71823673,
#        'lng': -73.99806087},
#       {'label': 'entrance', 'lat': 40.71815, 'lng': -73.998127}],
#      'distance': 965,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['182 Hester St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d165941735',
#       'name': 'Scenic Lookout',
#       'pluralName': 'Scenic Lookouts',
#       'shortName': 'Scenic Lookout',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4eb57638dab4fe5111a8a9d0',
#     'name': 'Italian American Prepared Foods',
#     'location': {'address': '78 - 84 Rivington',
#      'crossStreet': 'Allen',
#      'lat': 40.720544,
#      'lng': -73.989655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.720544,
#        'lng': -73.989655}],
#      'distance': 1719,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['78 - 84 Rivington (Allen)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4f779e12e4b08e5a67d80bb4',
#     'name': 'Diva italian resturant',
#     'location': {'address': '341 W Broadway',
#      'crossStreet': 'None',
#      'lat': 40.72306551231227,
#      'lng': -74.00372874071756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72306551231227,
#        'lng': -74.00372874071756},
#       {'label': 'entrance', 'lat': 40.722538, 'lng': -74.003473}],
#      'distance': 962,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['341 W Broadway (None)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4be0ac9398f2a593aa10c35a',
#     'name': "Carmine's Italian Seafood",
#     'location': {'address': '140 Beekman St',
#      'lat': 40.707375,
#      'lng': -74.0027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707375,
#        'lng': -74.0027}],
#      'distance': 1026,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['140 Beekman St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4bbf6b6430c99c74302a5511',
#     'name': 'PJ Charlton Italian Restaurant',
#     'location': {'address': '549 Greenwich St',
#      'lat': 40.72744633153894,
#      'lng': -74.00865622880806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72744633153894,
#        'lng': -74.00865622880806},
#       {'label': 'entrance', 'lat': 40.727328, 'lng': -74.008749}],
#      'distance': 1348,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['549 Greenwich St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '5323c9e6498e51e76d30cb8f',
#     'name': 'luca italian bar',
#     'location': {'lat': 40.723228,
#      'lng': -74.00112,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.723228,
#        'lng': -74.00112}],
#      'distance': 1093,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4b6c4ebaf964a520612f2ce3',
#     'name': 'Olive Tree Italian',
#     'location': {'address': '182 Lexington Ave',
#      'crossStreet': 'btw 31st & 32nd',
#      'lat': 40.744492,
#      'lng': -73.980835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744492,
#        'lng': -73.980835}],
#      'distance': 4014,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['182 Lexington Ave (btw 31st & 32nd)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '53132d23498eacec1e539180',
#     'name': 'Center for Italian Modern Art',
#     'location': {'address': '421 Broome St Fl 4',
#      'crossStreet': 'Crosby St',
#      'lat': 40.72118752815872,
#      'lng': -73.99851539989318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72118752815872,
#        'lng': -73.99851539989318}],
#      'distance': 1088,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['421 Broome St Fl 4 (Crosby St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5209ee81ee3',
#     'name': 'Carmine’s Italian Restaurant',
#     'location': {'address': '200 W 44th St',
#      'crossStreet': 'btwn Broadway & 8th Ave',
#      'lat': 40.7574973,
#      'lng': -73.9867788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7574973,
#        'lng': -73.9867788}],
#      'distance': 5048,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 W 44th St (btwn Broadway & 8th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False},
#    {'id': '4db8b4a46a2334682d993ff6',
#     'name': 'Carbon Italian Restaurant',
#     'location': {'address': '331 W 38th St',
#      'crossStreet': '8th avenue and 9th',
#      'lat': 40.755505294147575,
#      'lng': -73.99300887473368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755505294147575,
#        'lng': -73.99300887473368},
#       {'label': 'entrance', 'lat': 40.755402, 'lng': -73.99304}],
#      'distance': 4666,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['331 W 38th St (8th avenue and 9th)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590119508',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe
# Out:
#                           id                                             name  \
# 0   4a4560a7f964a5201aa81fe3  Harry's Italian Pizza Bar
# 1   4b9d4c67f964a5206ca136e3  Italian American Museum Of New York
# 2   4a74a36af964a520fede1fe3  Faicco's Italian Specialties
# 3   3fd66200f964a520f4e41ee3  Ecco
# 4   4f3232e219836c91c7bfde94  Conca Cucina Italian Restaurant
# 5   4fa862b3e4b0ebff2f749f06  Harry's Italian Pizza Bar
# 6   58dd8ac3a8b75966fda9a547  Tableside Italian Cook Shoppe
# 7   4e4c4e62bd413c4cc6686059  Carmela's Italian Specialties
# 8   528bf16711d2b7722da6b51c  Pisillo Italian Panini
# 9   4cf7d538dc40a35d26894f54  Italian Culinary Academy
# 10  51a63ef7498e9eedb94e0c5f  Italian Food Center
# 11  4e4c4d28bd413c4cc66857a5  Caruso's Italian Restaurant
# 12  5c893ef0d8096e0039e7363b  Pisillo Italian Panini
# 13  5400c682498e3831aaada9fc  Alex's Italian Restaurant & Brick Oven Pizza
# 14  4f3feae2e4b0ac9416a72118  Benvenuti Italian Specialties
# 15  588a4316326c5a4b60559f17  Pisillo Italian Cafe
# 16  50de11fde4b0a94f4e13d7cd  Italian Bakery 160 Prince
# 17  4b269f5af964a520817e24e3  Losurdo Brothers / Tony's Italian Bakery & Deli
# 18  4c3b8244def90f478f0ffe2d  Barber Italian Shop
# 19  4bd78b4809ecb7138732477c  Italian Rifle Club
# 20  4d97923e61a3a1cdb92ab942  Little Italian Rooftop
# 21  4eb57638dab4fe5111a8a9d0  Italian American Prepared Foods
# 22  4f779e12e4b08e5a67d80bb4  Diva italian resturant
# 23  4be0ac9398f2a593aa10c35a  Carmine's Italian Seafood
# 24  4bbf6b6430c99c74302a5511  PJ Charlton Italian Restaurant
# 25  5323c9e6498e51e76d30cb8f  luca italian bar
# 26  4b6c4ebaf964a520612f2ce3  Olive Tree Italian
# 27  53132d23498eacec1e539180  Center for Italian Modern Art
# 28  3fd66200f964a5209ee81ee3  Carmine’s Italian Restaurant
# 29  4db8b4a46a2334682d993ff6  Carbon Italian Restaurant
#
#                                                                                                                                                                                                                                                             categories  \
# 0   [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 1   [{'id': '4bf58dd8d48988d190941735', 'name': 'History Museum', 'pluralName': 'History Museums', 'shortName': 'History Museum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_', 'suffix': '.png'}, 'primary': True}]
# 2   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'Sandwich Place', 'pluralName': 'Sandwich Places', 'shortName': 'Sandwiches', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}, 'primary': True}]
# 3   [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 4   [{'id': '4d4b7105d754a06374d81259', 'name': 'Food', 'pluralName': 'Food', 'shortName': 'Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 5   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}, 'primary': True}]
# 6   [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 7   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}, 'primary': True}]
# 8   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'Sandwich Place', 'pluralName': 'Sandwich Places', 'shortName': 'Sandwiches', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}, 'primary': True}]
# 9   [{'id': '4bf58dd8d48988d199941735', 'name': 'College Arts Building', 'pluralName': 'College Arts Buildings', 'shortName': 'Arts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}]
# 10  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 11  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 12  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'Sandwich Place', 'pluralName': 'Sandwich Places', 'shortName': 'Sandwiches', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}, 'primary': True}]
# 13  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 14  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'Gourmet Shop', 'pluralName': 'Gourmet Shops', 'shortName': 'Gourmet', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_', 'suffix': '.png'}, 'primary': True}]
# 15  [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# 16  [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# 17  [{'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}, 'primary': True}]
# 18  [{'id': '4bf58dd8d48988d103951735', 'name': 'Clothing Store', 'pluralName': 'Clothing Stores', 'shortName': 'Apparel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_', 'suffix': '.png'}, 'primary': True}]
# 19  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 20  [{'id': '4bf58dd8d48988d165941735', 'name': 'Scenic Lookout', 'pluralName': 'Scenic Lookouts', 'shortName': 'Scenic Lookout', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_', 'suffix': '.png'}, 'primary': True}]
# 21  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 22  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 23  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 24  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 25  [{'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}, 'primary': True}]
# 26  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 27  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}, 'primary': True}]
# 28  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 29  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
#
#       referralId  hasPerk    location.address         location.crossStreet  \
# 0   v-1590119508  False    2 Gold St           at Maiden Ln.
# 1   v-1590119508  False    155 Mulberry St     at Grand St
# 2   v-1590119508  False    260 Bleecker St     at Cornelia St
# 3   v-1590119508  False    124 Chambers St     btwn Church St & W Broadway
# 4   v-1590119508  False    63 W Broadway       NaN
# 5   v-1590119508  False    225 Murray St       NaN
# 6   v-1590119508  False    345 E 6th St        1st and 2nd Ave
# 7   v-1590119508  False    30 Water St         NaN
# 8   v-1590119508  False    97 Nassau St        at Ann St
# 9   v-1590119508  False    462 Broadway        Grand St.
# 10  v-1590119508  False    161 Mulberry St     at Grand St.
# 11  v-1590119508  False    42 Broadway         NaN
# 12  v-1590119508  False    124 W 25th St       btwn 6th & 7th Ave
# 13  v-1590119508  False    346 Grove St        NaN
# 14  v-1590119508  False    235 S End Ave       NaN
# 15  v-1590119508  False    NaN                 NaN
# 16  v-1590119508  False    NaN                 NaN
# 17  v-1590119508  False    410 2nd St          btw Grand St & Adams St
# 18  v-1590119508  False    120 Broadway        btw Cedar & Pine
# 19  v-1590119508  False    NaN                 NaN
# 20  v-1590119508  False    182 Hester St       NaN
# 21  v-1590119508  False    78 - 84 Rivington   Allen
# 22  v-1590119508  False    341 W Broadway      None
# 23  v-1590119508  False    140 Beekman St      NaN
# 24  v-1590119508  False    549 Greenwich St    NaN
# 25  v-1590119508  False    NaN                 NaN
# 26  v-1590119508  False    182 Lexington Ave   btw 31st & 32nd
# 27  v-1590119508  False    421 Broome St Fl 4  Crosby St
# 28  v-1590119508  False    200 W 44th St       btwn Broadway & 8th Ave
# 29  v-1590119508  False    331 W 38th St       8th avenue and 9th
#
#     location.lat  location.lng  \
# 0   40.707634    -74.006996
# 1   40.719191    -73.997376
# 2   40.731117    -74.003043
# 3   40.715337    -74.008848
# 4   40.714484    -74.009806
# 5   40.715218    -74.014739
# 6   40.726556    -73.986514
# 7   40.719812    -74.035041
# 8   40.710530    -74.007526
# 9   40.718838    -73.997835
# 10  40.719589    -73.997339
# 11  40.710509    -74.008276
# 12  40.744566    -73.992868
# 13  40.720585    -74.042752
# 14  40.709681    -74.016520
# 15  40.710493    -74.007546
# 16  40.725955    -74.001161
# 17  40.740126    -74.036964
# 18  40.707970    -74.009949
# 19  40.728589    -74.001743
# 20  40.718237    -73.998061
# 21  40.720544    -73.989655
# 22  40.723066    -74.003729
# 23  40.707375    -74.002700
# 24  40.727446    -74.008656
# 25  40.723228    -74.001120
# 26  40.744492    -73.980835
# 27  40.721188    -73.998515
# 28  40.757497    -73.986779
# 29  40.755505    -73.993009
#
#                                                                                                                     location.labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 40.7076335455641, 'lng': -74.00699585960496}]
# 1   [{'label': 'display', 'lat': 40.71919065572268, 'lng': -73.99737599769244}]
# 2   [{'label': 'display', 'lat': 40.73111661087598, 'lng': -74.0030425786972}]
# 3   [{'label': 'display', 'lat': 40.71533713859952, 'lng': -74.00884766217825}, {'label': 'entrance', 'lat': 40.715202, 'lng': -74.008779}]
# 4   [{'label': 'display', 'lat': 40.714484000000006, 'lng': -74.00980600000001}]
# 5   [{'label': 'display', 'lat': 40.71521779064671, 'lng': -74.01473940209351}, {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}]
# 6   [{'label': 'display', 'lat': 40.726556174383305, 'lng': -73.98651414092868}]
# 7   [{'label': 'display', 'lat': 40.71981178398971, 'lng': -74.03504130880152}]
# 8   [{'label': 'display', 'lat': 40.710530084460785, 'lng': -74.00752571804911}]
# 9   [{'label': 'display', 'lat': 40.71883786954379, 'lng': -73.99783518413365}]
# 10  [{'label': 'display', 'lat': 40.719589, 'lng': -73.997339}, {'label': 'entrance', 'lat': 40.719579, 'lng': -73.997296}]
# 11  [{'label': 'display', 'lat': 40.710509099999996, 'lng': -74.00827615}]
# 12  [{'label': 'display', 'lat': 40.744566, 'lng': -73.992868}, {'label': 'entrance', 'lat': 40.744568, 'lng': -73.992984}]
# 13  [{'label': 'display', 'lat': 40.72058470693942, 'lng': -74.04275196874856}]
# 14  [{'label': 'display', 'lat': 40.70968105555279, 'lng': -74.01652043988257}]
# 15  [{'label': 'display', 'lat': 40.71049280792626, 'lng': -74.00754611675153}]
# 16  [{'label': 'display', 'lat': 40.725955, 'lng': -74.001161}]
# 17  [{'label': 'display', 'lat': 40.74012586093679, 'lng': -74.0369639338283}]
# 18  [{'label': 'display', 'lat': 40.70796968555732, 'lng': -74.00994920143108}]
# 19  [{'label': 'display', 'lat': 40.72858856840826, 'lng': -74.00174320053318}]
# 20  [{'label': 'display', 'lat': 40.71823673, 'lng': -73.99806087}, {'label': 'entrance', 'lat': 40.71815, 'lng': -73.998127}]
# 21  [{'label': 'display', 'lat': 40.720544, 'lng': -73.989655}]
# 22  [{'label': 'display', 'lat': 40.72306551231227, 'lng': -74.00372874071756}, {'label': 'entrance', 'lat': 40.722538, 'lng': -74.003473}]
# 23  [{'label': 'display', 'lat': 40.707375, 'lng': -74.0027}]
# 24  [{'label': 'display', 'lat': 40.72744633153894, 'lng': -74.00865622880806}, {'label': 'entrance', 'lat': 40.727328, 'lng': -74.008749}]
# 25  [{'label': 'display', 'lat': 40.723228, 'lng': -74.00112}]
# 26  [{'label': 'display', 'lat': 40.744492, 'lng': -73.980835}]
# 27  [{'label': 'display', 'lat': 40.72118752815872, 'lng': -73.99851539989318}]
# 28  [{'label': 'display', 'lat': 40.7574973, 'lng': -73.9867788}]
# 29  [{'label': 'display', 'lat': 40.755505294147575, 'lng': -73.99300887473368}, {'label': 'entrance', 'lat': 40.755402, 'lng': -73.99304}]
#
#     ...  location.country  \
# 0   ...  United States
# 1   ...  United States
# 2   ...  United States
# 3   ...  United States
# 4   ...  United States
# 5   ...  United States
# 6   ...  United States
# 7   ...  United States
# 8   ...  United States
# 9   ...  United States
# 10  ...  United States
# 11  ...  United States
# 12  ...  United States
# 13  ...  United States
# 14  ...  United States
# 15  ...  United States
# 16  ...  United States
# 17  ...  United States
# 18  ...  United States
# 19  ...  United States
# 20  ...  United States
# 21  ...  United States
# 22  ...  United States
# 23  ...  United States
# 24  ...  United States
# 25  ...  United States
# 26  ...  United States
# 27  ...  United States
# 28  ...  United States
# 29  ...  United States
#
#                                                              location.formattedAddress  \
# 0   [2 Gold St (at Maiden Ln.), New York, NY 10038, United States]
# 1   [155 Mulberry St (at Grand St), New York, NY 10013, United States]
# 2   [260 Bleecker St (at Cornelia St), New York, NY 10014, United States]
# 3   [124 Chambers St (btwn Church St & W Broadway), New York, NY 10007, United States]
# 4   [63 W Broadway, New York, NY 10007, United States]
# 5   [225 Murray St, New York, NY 10282, United States]
# 6   [345 E 6th St (1st and 2nd Ave), New York, NY 10003, United States]
# 7   [30 Water St, New York, NJ 10004, United States]
# 8   [97 Nassau St (at Ann St), New York, NY 10038, United States]
# 9   [462 Broadway (Grand St.), New York, NY 10013, United States]
# 10  [161 Mulberry St (at Grand St.), New York, NY 10013, United States]
# 11  [42 Broadway, New York, NY 10004, United States]
# 12  [124 W 25th St (btwn 6th & 7th Ave), New York, NY 10001, United States]
# 13  [346 Grove St, Jersey City, NJ 07302, United States]
# 14  [235 S End Ave, New York, NY 10280, United States]
# 15  [New York, NY, United States]
# 16  [New York, NY 10012, United States]
# 17  [410 2nd St (btw Grand St & Adams St), Hoboken, NJ 07030, United States]
# 18  [120 Broadway (btw Cedar & Pine), New York, NY 10271, United States]
# 19  [New York, NY 10012, United States]
# 20  [182 Hester St, New York, NY 10013, United States]
# 21  [78 - 84 Rivington (Allen), New York, NY 10002, United States]
# 22  [341 W Broadway (None), New York, NY 10013, United States]
# 23  [140 Beekman St, New York, NY 10038, United States]
# 24  [549 Greenwich St, New York, NY 10013, United States]
# 25  [New York, NY, United States]
# 26  [182 Lexington Ave (btw 31st & 32nd), New York, NY 10016, United States]
# 27  [421 Broome St Fl 4 (Crosby St), New York, NY 10013, United States]
# 28  [200 W 44th St (btwn Broadway & 8th Ave), New York, NY 10036, United States]
# 29  [331 W 38th St (8th avenue and 9th), New York, NY 10018, United States]
#
#    venuePage.id delivery.id  \
# 0   77559825     NaN
# 1   66342615     NaN
# 2   NaN          NaN
# 3   NaN          NaN
# 4   NaN          NaN
# 5   NaN          NaN
# 6   427907002    1700675
# 7   NaN          NaN
# 8   105457747    286355
# 9   NaN          NaN
# 10  NaN          NaN
# 11  NaN          NaN
# 12  NaN          1108715
# 13  NaN          294871
# 14  NaN          NaN
# 15  NaN          NaN
# 16  NaN          NaN
# 17  NaN          NaN
# 18  NaN          NaN
# 19  NaN          NaN
# 20  NaN          NaN
# 21  NaN          NaN
# 22  NaN          NaN
# 23  NaN          NaN
# 24  NaN          NaN
# 25  NaN          NaN
# 26  NaN          NaN
# 27  NaN          NaN
# 28  NaN          NaN
# 29  NaN          NaN
#
#                                                                                                                                                                                                              delivery.url  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   https://www.seamless.com/menu/tableside-italian-cook-shoppe-345-e-6th-st-new-york/1700675?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1700675
# 7   NaN
# 8   https://www.seamless.com/menu/pisillo-97-nassau-st-new-york/286355?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=286355
# 9   NaN
# 10  NaN
# 11  NaN
# 12  https://www.seamless.com/menu/pisillo-124-w-25th-st-new-york/1108715?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1108715
# 13  https://www.grubhub.com/restaurant/alex-pizza-and-italian-restaurant-346-grove-st-jersey-city/294871?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294871
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
#
#    delivery.provider.name             delivery.provider.icon.prefix  \
# 0   NaN                    NaN
# 1   NaN                    NaN
# 2   NaN                    NaN
# 3   NaN                    NaN
# 4   NaN                    NaN
# 5   NaN                    NaN
# 6   seamless               https://fastly.4sqi.net/img/general/cap/
# 7   NaN                    NaN
# 8   seamless               https://fastly.4sqi.net/img/general/cap/
# 9   NaN                    NaN
# 10  NaN                    NaN
# 11  NaN                    NaN
# 12  seamless               https://fastly.4sqi.net/img/general/cap/
# 13  grubhub                https://fastly.4sqi.net/img/general/cap/
# 14  NaN                    NaN
# 15  NaN                    NaN
# 16  NaN                    NaN
# 17  NaN                    NaN
# 18  NaN                    NaN
# 19  NaN                    NaN
# 20  NaN                    NaN
# 21  NaN                    NaN
# 22  NaN                    NaN
# 23  NaN                    NaN
# 24  NaN                    NaN
# 25  NaN                    NaN
# 26  NaN                    NaN
# 27  NaN                    NaN
# 28  NaN                    NaN
# 29  NaN                    NaN
#
#    delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0   NaN                          NaN
# 1   NaN                          NaN
# 2   NaN                          NaN
# 3   NaN                          NaN
# 4   NaN                          NaN
# 5   NaN                          NaN
# 6   [40, 50]                     /delivery_provider_seamless_20180129.png
# 7   NaN                          NaN
# 8   [40, 50]                     /delivery_provider_seamless_20180129.png
# 9   NaN                          NaN
# 10  NaN                          NaN
# 11  NaN                          NaN
# 12  [40, 50]                     /delivery_provider_seamless_20180129.png
# 13  [40, 50]                     /delivery_provider_grubhub_20180129.png
# 14  NaN                          NaN
# 15  NaN                          NaN
# 16  NaN                          NaN
# 17  NaN                          NaN
# 18  NaN                          NaN
# 19  NaN                          NaN
# 20  NaN                          NaN
# 21  NaN                          NaN
# 22  NaN                          NaN
# 23  NaN                          NaN
# 24  NaN                          NaN
# 25  NaN                          NaN
# 26  NaN                          NaN
# 27  NaN                          NaN
# 28  NaN                          NaN
# 29  NaN                          NaN
#
#    location.neighborhood
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  Chelsea
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
#
# [30 rows x 25 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name             categories  \
# 0   Harry's Italian Pizza Bar                        Italian Restaurant
# 1   Italian American Museum Of New York              History Museum
# 2   Faicco's Italian Specialties                     Sandwich Place
# 3   Ecco                                             Italian Restaurant
# 4   Conca Cucina Italian Restaurant                  Food
# 5   Harry's Italian Pizza Bar                        Pizza Place
# 6   Tableside Italian Cook Shoppe                    Italian Restaurant
# 7   Carmela's Italian Specialties                    Pizza Place
# 8   Pisillo Italian Panini                           Sandwich Place
# 9   Italian Culinary Academy                         College Arts Building
# 10  Italian Food Center                              Italian Restaurant
# 11  Caruso's Italian Restaurant                      Italian Restaurant
# 12  Pisillo Italian Panini                           Sandwich Place
# 13  Alex's Italian Restaurant & Brick Oven Pizza     Italian Restaurant
# 14  Benvenuti Italian Specialties                    Gourmet Shop
# 15  Pisillo Italian Cafe                             Café
# 16  Italian Bakery 160 Prince                        Bakery
# 17  Losurdo Brothers / Tony's Italian Bakery & Deli  Bakery
# 18  Barber Italian Shop                              Clothing Store
# 19  Italian Rifle Club                               Italian Restaurant
# 20  Little Italian Rooftop                           Scenic Lookout
# 21  Italian American Prepared Foods                  Italian Restaurant
# 22  Diva italian resturant                           Italian Restaurant
# 23  Carmine's Italian Seafood                        Italian Restaurant
# 24  PJ Charlton Italian Restaurant                   Italian Restaurant
# 25  luca italian bar                                 Cocktail Bar
# 26  Olive Tree Italian                               Italian Restaurant
# 27  Center for Italian Modern Art                    Art Gallery
# 28  Carmine’s Italian Restaurant                     Italian Restaurant
# 29  Carbon Italian Restaurant                        Italian Restaurant
#
#                address                  crossStreet        lat        lng  \
# 0   2 Gold St           at Maiden Ln.                40.707634 -74.006996
# 1   155 Mulberry St     at Grand St                  40.719191 -73.997376
# 2   260 Bleecker St     at Cornelia St               40.731117 -74.003043
# 3   124 Chambers St     btwn Church St & W Broadway  40.715337 -74.008848
# 4   63 W Broadway       NaN                          40.714484 -74.009806
# 5   225 Murray St       NaN                          40.715218 -74.014739
# 6   345 E 6th St        1st and 2nd Ave              40.726556 -73.986514
# 7   30 Water St         NaN                          40.719812 -74.035041
# 8   97 Nassau St        at Ann St                    40.710530 -74.007526
# 9   462 Broadway        Grand St.                    40.718838 -73.997835
# 10  161 Mulberry St     at Grand St.                 40.719589 -73.997339
# 11  42 Broadway         NaN                          40.710509 -74.008276
# 12  124 W 25th St       btwn 6th & 7th Ave           40.744566 -73.992868
# 13  346 Grove St        NaN                          40.720585 -74.042752
# 14  235 S End Ave       NaN                          40.709681 -74.016520
# 15  NaN                 NaN                          40.710493 -74.007546
# 16  NaN                 NaN                          40.725955 -74.001161
# 17  410 2nd St          btw Grand St & Adams St      40.740126 -74.036964
# 18  120 Broadway        btw Cedar & Pine             40.707970 -74.009949
# 19  NaN                 NaN                          40.728589 -74.001743
# 20  182 Hester St       NaN                          40.718237 -73.998061
# 21  78 - 84 Rivington   Allen                        40.720544 -73.989655
# 22  341 W Broadway      None                         40.723066 -74.003729
# 23  140 Beekman St      NaN                          40.707375 -74.002700
# 24  549 Greenwich St    NaN                          40.727446 -74.008656
# 25  NaN                 NaN                          40.723228 -74.001120
# 26  182 Lexington Ave   btw 31st & 32nd              40.744492 -73.980835
# 27  421 Broome St Fl 4  Crosby St                    40.721188 -73.998515
# 28  200 W 44th St       btwn Broadway & 8th Ave      40.757497 -73.986779
# 29  331 W 38th St       8th avenue and 9th           40.755505 -73.993009
#
#                                                                                                                              labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 40.7076335455641, 'lng': -74.00699585960496}]
# 1   [{'label': 'display', 'lat': 40.71919065572268, 'lng': -73.99737599769244}]
# 2   [{'label': 'display', 'lat': 40.73111661087598, 'lng': -74.0030425786972}]
# 3   [{'label': 'display', 'lat': 40.71533713859952, 'lng': -74.00884766217825}, {'label': 'entrance', 'lat': 40.715202, 'lng': -74.008779}]
# 4   [{'label': 'display', 'lat': 40.714484000000006, 'lng': -74.00980600000001}]
# 5   [{'label': 'display', 'lat': 40.71521779064671, 'lng': -74.01473940209351}, {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}]
# 6   [{'label': 'display', 'lat': 40.726556174383305, 'lng': -73.98651414092868}]
# 7   [{'label': 'display', 'lat': 40.71981178398971, 'lng': -74.03504130880152}]
# 8   [{'label': 'display', 'lat': 40.710530084460785, 'lng': -74.00752571804911}]
# 9   [{'label': 'display', 'lat': 40.71883786954379, 'lng': -73.99783518413365}]
# 10  [{'label': 'display', 'lat': 40.719589, 'lng': -73.997339}, {'label': 'entrance', 'lat': 40.719579, 'lng': -73.997296}]
# 11  [{'label': 'display', 'lat': 40.710509099999996, 'lng': -74.00827615}]
# 12  [{'label': 'display', 'lat': 40.744566, 'lng': -73.992868}, {'label': 'entrance', 'lat': 40.744568, 'lng': -73.992984}]
# 13  [{'label': 'display', 'lat': 40.72058470693942, 'lng': -74.04275196874856}]
# 14  [{'label': 'display', 'lat': 40.70968105555279, 'lng': -74.01652043988257}]
# 15  [{'label': 'display', 'lat': 40.71049280792626, 'lng': -74.00754611675153}]
# 16  [{'label': 'display', 'lat': 40.725955, 'lng': -74.001161}]
# 17  [{'label': 'display', 'lat': 40.74012586093679, 'lng': -74.0369639338283}]
# 18  [{'label': 'display', 'lat': 40.70796968555732, 'lng': -74.00994920143108}]
# 19  [{'label': 'display', 'lat': 40.72858856840826, 'lng': -74.00174320053318}]
# 20  [{'label': 'display', 'lat': 40.71823673, 'lng': -73.99806087}, {'label': 'entrance', 'lat': 40.71815, 'lng': -73.998127}]
# 21  [{'label': 'display', 'lat': 40.720544, 'lng': -73.989655}]
# 22  [{'label': 'display', 'lat': 40.72306551231227, 'lng': -74.00372874071756}, {'label': 'entrance', 'lat': 40.722538, 'lng': -74.003473}]
# 23  [{'label': 'display', 'lat': 40.707375, 'lng': -74.0027}]
# 24  [{'label': 'display', 'lat': 40.72744633153894, 'lng': -74.00865622880806}, {'label': 'entrance', 'lat': 40.727328, 'lng': -74.008749}]
# 25  [{'label': 'display', 'lat': 40.723228, 'lng': -74.00112}]
# 26  [{'label': 'display', 'lat': 40.744492, 'lng': -73.980835}]
# 27  [{'label': 'display', 'lat': 40.72118752815872, 'lng': -73.99851539989318}]
# 28  [{'label': 'display', 'lat': 40.7574973, 'lng': -73.9867788}]
# 29  [{'label': 'display', 'lat': 40.755505294147575, 'lng': -73.99300887473368}, {'label': 'entrance', 'lat': 40.755402, 'lng': -73.99304}]
#
#     distance postalCode  cc         city state        country  \
# 0   871       10038      US  New York     NY    United States
# 1   1058      10013      US  New York     NY    United States
# 2   1823      10014      US  New York     NY    United States
# 3   0         10007      US  New York     NY    United States
# 4   124       10007      US  New York     NY    United States
# 5   497       10282      US  New York     NY    United States
# 6   2260      10003      US  New York     NY    United States
# 7   2265      10004      US  New York     NJ    United States
# 8   546       10038      US  New York     NY    United States
# 9   1007      10013      US  New York     NY    United States
# 10  1080      10013      US  New York     NY    United States
# 11  539       10004      US  New York     NY    United States
# 12  3521      10001      US  New York     NY    United States
# 13  2919      07302      US  Jersey City  NJ    United States
# 14  903       10280      US  New York     NY    United States
# 15  550       NaN        US  New York     NY    United States
# 16  1348      10012      US  New York     NY    United States
# 17  3638      07030      US  Hoboken      NJ    United States
# 18  825       10271      US  New York     NY    United States
# 19  1592      10012      US  New York     NY    United States
# 20  965       10013      US  New York     NY    United States
# 21  1719      10002      US  New York     NY    United States
# 22  962       10013      US  New York     NY    United States
# 23  1026      10038      US  New York     NY    United States
# 24  1348      10013      US  New York     NY    United States
# 25  1093      NaN        US  New York     NY    United States
# 26  4014      10016      US  New York     NY    United States
# 27  1088      10013      US  New York     NY    United States
# 28  5048      10036      US  New York     NY    United States
# 29  4666      10018      US  New York     NY    United States
#
#                                                                       formattedAddress  \
# 0   [2 Gold St (at Maiden Ln.), New York, NY 10038, United States]
# 1   [155 Mulberry St (at Grand St), New York, NY 10013, United States]
# 2   [260 Bleecker St (at Cornelia St), New York, NY 10014, United States]
# 3   [124 Chambers St (btwn Church St & W Broadway), New York, NY 10007, United States]
# 4   [63 W Broadway, New York, NY 10007, United States]
# 5   [225 Murray St, New York, NY 10282, United States]
# 6   [345 E 6th St (1st and 2nd Ave), New York, NY 10003, United States]
# 7   [30 Water St, New York, NJ 10004, United States]
# 8   [97 Nassau St (at Ann St), New York, NY 10038, United States]
# 9   [462 Broadway (Grand St.), New York, NY 10013, United States]
# 10  [161 Mulberry St (at Grand St.), New York, NY 10013, United States]
# 11  [42 Broadway, New York, NY 10004, United States]
# 12  [124 W 25th St (btwn 6th & 7th Ave), New York, NY 10001, United States]
# 13  [346 Grove St, Jersey City, NJ 07302, United States]
# 14  [235 S End Ave, New York, NY 10280, United States]
# 15  [New York, NY, United States]
# 16  [New York, NY 10012, United States]
# 17  [410 2nd St (btw Grand St & Adams St), Hoboken, NJ 07030, United States]
# 18  [120 Broadway (btw Cedar & Pine), New York, NY 10271, United States]
# 19  [New York, NY 10012, United States]
# 20  [182 Hester St, New York, NY 10013, United States]
# 21  [78 - 84 Rivington (Allen), New York, NY 10002, United States]
# 22  [341 W Broadway (None), New York, NY 10013, United States]
# 23  [140 Beekman St, New York, NY 10038, United States]
# 24  [549 Greenwich St, New York, NY 10013, United States]
# 25  [New York, NY, United States]
# 26  [182 Lexington Ave (btw 31st & 32nd), New York, NY 10016, United States]
# 27  [421 Broome St Fl 4 (Crosby St), New York, NY 10013, United States]
# 28  [200 W 44th St (btwn Broadway & 8th Ave), New York, NY 10036, United States]
# 29  [331 W 38th St (8th avenue and 9th), New York, NY 10018, United States]
#
#    neighborhood                        id
# 0   NaN          4a4560a7f964a5201aa81fe3
# 1   NaN          4b9d4c67f964a5206ca136e3
# 2   NaN          4a74a36af964a520fede1fe3
# 3   NaN          3fd66200f964a520f4e41ee3
# 4   NaN          4f3232e219836c91c7bfde94
# 5   NaN          4fa862b3e4b0ebff2f749f06
# 6   NaN          58dd8ac3a8b75966fda9a547
# 7   NaN          4e4c4e62bd413c4cc6686059
# 8   NaN          528bf16711d2b7722da6b51c
# 9   NaN          4cf7d538dc40a35d26894f54
# 10  NaN          51a63ef7498e9eedb94e0c5f
# 11  NaN          4e4c4d28bd413c4cc66857a5
# 12  Chelsea      5c893ef0d8096e0039e7363b
# 13  NaN          5400c682498e3831aaada9fc
# 14  NaN          4f3feae2e4b0ac9416a72118
# 15  NaN          588a4316326c5a4b60559f17
# 16  NaN          50de11fde4b0a94f4e13d7cd
# 17  NaN          4b269f5af964a520817e24e3
# 18  NaN          4c3b8244def90f478f0ffe2d
# 19  NaN          4bd78b4809ecb7138732477c
# 20  NaN          4d97923e61a3a1cdb92ab942
# 21  NaN          4eb57638dab4fe5111a8a9d0
# 22  NaN          4f779e12e4b08e5a67d80bb4
# 23  NaN          4be0ac9398f2a593aa10c35a
# 24  NaN          4bbf6b6430c99c74302a5511
# 25  NaN          5323c9e6498e51e76d30cb8f
# 26  NaN          4b6c4ebaf964a520612f2ce3
# 27  NaN          53132d23498eacec1e539180
# 28  NaN          3fd66200f964a5209ee81ee3
# 29  NaN          4db8b4a46a2334682d993ff6

# %%
dataframe_filtered.name
# Out:
# 0     Harry's Italian Pizza Bar
# 1     Italian American Museum Of New York
# 2     Faicco's Italian Specialties
# 3     Ecco
# 4     Conca Cucina Italian Restaurant
# 5     Harry's Italian Pizza Bar
# 6     Tableside Italian Cook Shoppe
# 7     Carmela's Italian Specialties
# 8     Pisillo Italian Panini
# 9     Italian Culinary Academy
# 10    Italian Food Center
# 11    Caruso's Italian Restaurant
# 12    Pisillo Italian Panini
# 13    Alex's Italian Restaurant & Brick Oven Pizza
# 14    Benvenuti Italian Specialties
# 15    Pisillo Italian Cafe
# 16    Italian Bakery 160 Prince
# 17    Losurdo Brothers / Tony's Italian Bakery & Deli
# 18    Barber Italian Shop
# 19    Italian Rifle Club
# 20    Little Italian Rooftop
# 21    Italian American Prepared Foods
# 22    Diva italian resturant
# 23    Carmine's Italian Seafood
# 24    PJ Charlton Italian Restaurant
# 25    luca italian bar
# 26    Olive Tree Italian
# 27    Center for Italian Modern Art
# 28    Carmine’s Italian Restaurant
# 29    Carbon Italian Restaurant
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Casa De Abuelita',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=3LOX1XCTNAEPXKSWU1NEMIZB21FN4YVONAVZSSUFFQS2BR3K&client_secret=JIMJSWLBD5UVHYYVUX34PBRAFB51G22ADXPDBJYNYN2NBDC0&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4fa862b3e4b0ebff2f749f06',
#  'name': "Harry's Italian Pizza Bar",
#  'contact': {'phone': '2126081007', 'formattedPhone': '(212) 608-1007'},
#  'location': {'address': '225 Murray St',
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351},
#    {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}],
#   'postalCode': '10282',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St',
#    'New York, NY 10282',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'shortName': 'Pizza',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 57},
#  'url': 'http://harrysitalian.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 120,
#   'groups': [{'type': 'others', 'count': 120, 'items': []}],
#   'summary': '120 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.4,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 212,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 146,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 146,
#     'items': [{'id': '4fad980de4b091b4626c3633',
#       'createdAt': 1336776717,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'width': 480,
#       'height': 640,
#       'user': {'id': '13676709',
#        'firstName': 'Leony',
#        'lastName': 'N',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public'},
#      {'id': '503139a5e4b021f7a5e9952a',
#       'createdAt': 1345403301,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/ox3MATx28ULVNhMemzwMx5ivrRPh0aIbowxREaHWzKA.jpg',
#       'width': 720,
#       'height': 540,
#       'user': {'id': '4434246',
#        'firstName': 'Gregory',
#        'lastName': 'L',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4XA1N04BRCPULL2M.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1336435379,
#  'tips': {'count': 57,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 57,
#     'items': [{'id': '53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'type': 'others',
#          'count': 4,
#          'items': [{'id': '369426',
#            'firstName': 'P.',
#            'lastName': 'M',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/JPQYUWJKUT0H2OO4.jpg'}},
#           {'id': '87587879',
#            'firstName': 'Diane',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'id': '87591341',
#            'firstName': 'Tim',
#            'lastName': 'S',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'id': '87473404',
#            'firstName': 'TenantKing.com',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}]}],
#        'summary': '4 likes'},
#       'logView': True,
#       'agreeCount': 4,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '87473404',
#        'firstName': 'TenantKing.com',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}},
#      {'id': '53962e98498ecd43845cc813',
#       'createdAt': 1402351256,
#       'text': "I'm not sure if this place is one of the famous pizzerias in NYC but I loved their pizza.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/53962e98498ecd43845cc813',
#       'photo': {'id': '53962e9c498e53dbbf59b28e',
#        'createdAt': 1402351260,
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/7012699_DCcCtW8oRbhNv62E68gxtLnWn7IgRhapBr8vdnIQjYk.jpg',
#        'width': 720,
#        'height': 720,
#        'visibility': 'public'},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/7012699_DCcCtW8oRbhNv62E68gxtLnWn7IgRhapBr8vdnIQjYk.jpg',
#       'lang': 'en',
#       'likes': {'count': 2,
#        'groups': [{'type': 'others',
#          'count': 2,
#          'items': [{'id': '7012699',
#            'firstName': 'Hani',
#            'lastName': 'A',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/7012699_vCXraeWA_FdHlUETPVuDaElNtnp76a2i4JWAyD1JVMMiqitsCujXhqKtV2MQYPdfAVMBI7BRi.jpg'}},
#           {'id': '61939758',
#            'firstName': 'Leena',
#            'lastName': 'R',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/61939758_KOpR9NFm_rNQPhjDng4f_qr3PU69nNGFgLnjwS-dM97MnkvrD7h1U2tOojRCPpFLq_B9KVfbh.jpg'}}]}],
#        'summary': '2 likes'},
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '7012699',
#        'firstName': 'Hani',
#        'lastName': 'A',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/7012699_vCXraeWA_FdHlUETPVuDaElNtnp76a2i4JWAyD1JVMMiqitsCujXhqKtV2MQYPdfAVMBI7BRi.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 54,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 54,
#     'items': [{'id': '4fa32fd0e4b04193744746b1',
#       'name': 'Manhattan Haunts',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '24592223',
#        'firstName': 'Becca',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'createdAt': 1336094672,
#       'updatedAt': 1380845377,
#       'photo': {'id': '4e8cc9461081e3b3544e12e5',
#        'createdAt': 1317849414,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'width': 492,
#        'height': 330,
#        'user': {'id': '742542',
#         'firstName': 'Time Out New York',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public'},
#       'followers': {'count': 22},
#       'listItems': {'count': 187,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1342934485}]}},
#      {'id': '4fae817be4b085f6b2a74d19',
#       'name': 'USA NYC MAN FiDi',
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'type': 'others',
#       'user': {'id': '12113441',
#        'firstName': 'Kino',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'createdAt': 1336836475,
#       'updatedAt': 1556754919,
#       'photo': {'id': '55984992498e13ba75e353bb',
#        'createdAt': 1436043666,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'width': 540,
#        'height': 960,
#        'user': {'id': '12113441',
#         'firstName': 'Kino',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 20},
#       'listItems': {'count': 273,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1373909433}]}},
#      {'id': '4fddeff0e4b0e078037ac0d3',
#       'name': 'NYC Resturants',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '21563126',
#        'firstName': 'Richard',
#        'lastName': 'R',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/rickr7/list/nyc-resturants',
#       'canonicalUrl': 'https://foursquare.com/rickr7/list/nyc-resturants',
#       'createdAt': 1339944944,
#       'updatedAt': 1589017010,
#       'photo': {'id': '5072dd13e4b09145cdf782d1',
#        'createdAt': 1349704979,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/208205_fGh2OuAZ9qJ4agbAA5wMVNOSIm9kNUlRtNwj1N-adqg.jpg',
#        'width': 800,
#        'height': 800,
#        'user': {'id': '208205',
#         'firstName': 'Thalia',
#         'lastName': 'K',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/SNOOLCAW2AG04ZKD.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 12},
#       'listItems': {'count': 192,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1581655865}]}},
#      {'id': '5266c68a498e7c667807fe09',
#       'name': 'Foodie Love in NY - 02',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '547977',
#        'firstName': 'WiLL',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-Q5NYGDMFDMOITQRR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/sweetiewill/list/foodie-love-in-ny--02',
#       'canonicalUrl': 'https://foursquare.com/sweetiewill/list/foodie-love-in-ny--02',
#       'createdAt': 1382467210,
#       'updatedAt': 1391995585,
#       'followers': {'count': 7},
#       'listItems': {'count': 200,
#        'items': [{'id': 'v4fa862b3e4b0ebff2f749f06',
#          'createdAt': 1386809936}]}}]}]},
#  'hours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Wed',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}]}]},
#  'bestPhoto': {'id': '4fad980de4b091b4626c3633',
#   'createdAt': 1336776717,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'width': 480,
#   'height': 640,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.4

# %% [markdown]
# That is not a very good rating. Let's check the rating of the second closest Italian restaurant.

# %%
venue_id = '4f3232e219836c91c7bfde94' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Since this restaurant has no ratings, let's check the third restaurant.

# %%
venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.4

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 19

# %% [markdown]
# ### D. Get the venue's tips
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Create URL and send GET request. Make sure to set limit to get all tips

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec74bfeb1cac0001b1d6dec'},
#  'response': {'tips': {'count': 19,
#    'items': [{'id': '5ab1cb46c9a517174651d3fe',
#      'createdAt': 1521601350,
#      'text': 'A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5ab1cb46c9a517174651d3fe',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 4,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '484542633',
#       'firstName': 'Nick',
#       'lastName': 'E',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/484542633_unymNUmw_FdPs3GjXHujmHcYnN4hf8kEPADlOZuIrdcdm97VX3tFqL7fFNMNA_8Gl9NlU1GYg.jpg'}},
#      'authorInteractionType': 'liked'},
#     {'id': '5cb7051b180b910039f90625',
#      'createdAt': 1555498267,
#      'text': 'Excellent food!! Osso bucco special one of the best I ever had! Lobster ravioli with porcini mushroomhomemade Italian cheesecake, tiramisu and napoleons...calamari fra diavolo was sautéed not fried',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5cb7051b180b910039f90625',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 1,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '446298346',
#       'firstName': 'Lynn',
#       'lastName': 'B',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/446298346_fdtqugvP_1WztOWXXDQX92HwIrjzLb6nMQsYiCVlkiTp58UGSFVBwQ0-5G5AdqxlEWphYWTnK.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %% [markdown]
# #### Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %% [markdown]
# #### Format column width and display all tips

# %%
pd.set_option('display.max_colwidth', None)

tips_df = pd.json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df[filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                                     text  \
# 0                     A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites
# 1  Excellent food!! Osso bucco special one of the best I ever had! Lobster ravioli with porcini mushroomhomemade Italian cheesecake, tiramisu and napoleons...calamari fra diavolo was sautéed not fried
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0           4              0  5ab1cb46c9a517174651d3fe           Nick
# 1           1              0  5cb7051b180b910039f90625           Lynn
#
#   user.lastName    user.id
# 0             E  484542633
# 1             B  446298346

# %% [markdown]
# <a id="item3"></a>

# %% [markdown]
# ## 3. Search a Foursquare User
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Define URL, send GET request and display features associated with user

# %%
user_id = '484542633' # user ID with most agree counts and complete profile
ACCESS_TOKEN = 'LFCKRDVG3LLR2JZT1PC0CTLCMQ1FD3UFN4OTSSMUNWEK2U22'

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['id', 'firstName', 'lastName', 'gender', 'canonicalUrl', 'photo', 'friends', 'tips', 'homeCity', 'bio', 'contact', 'photos', 'checkinPings', 'pings', 'type', 'mayorships', 'checkins', 'lists', 'blockedStatus', 'lenses'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
# Out:
# First Name: Nick
# Last Name: El-Tawil
# Home City: New York, NY

# %% [markdown]
# #### How many tips has this user submitted?

# %%
user_data['tips']
# Out:
# {'count': 98}

# %% [markdown]
# ### Get User's tips

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
# C:\Users\jalma\Documents\Anaconda3\Anaconda3_Files\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if __name__ == '__main__':
# C:\Users\jalma\Documents\Anaconda3\Anaconda3_Files\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
#                                                                                                                                                                                                text  \
# 0   They serve coffee!!!!!!
# 1   Quick, cheap lunch that tastes good! Way shorter line than Chipotle, too.
# 2   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am
# 3   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪
# 4   Burger game strong 💪
# 5   Great burgers & fries! Also, this place is exactly what it’s like when you go to a bar in the Southwest. Source: I’m from Arizona.
# 6   Açaí bowl + peanut butter + whey protein = 💪💪💪
# 7   Highly underrated and way less crowded than Central Park!
# 8   Way easier to navigate than the Met proper, plus the Met Breuer focuses on modern art. If I only have a limited amount of time to spend in a museum, I would rather go here than anywhere else!
# 9   Get the açaí bowl with peanut butter after your work out and thank me later 👌
# 10  When you want a burger, this should be the first thing that comes to mind. A+!
# 11  Way less crowded than Central Park! People who live in the neighborhood rave about Carl Schurz Park.
# 12  The best Mexican food in the Murray Hill / Kips Bay area!
# 13  Best coffee shop in the neighborhood!
# 14  When there’s nice weather, the rooftop at Tonic East is the best place to watch the game. Perfect for March Madness & NBA finals!
#
#     agreeCount  disagreeCount                        id
# 0   1           0              5accc98c0313204c9d7ec157
# 1   2           0              5acbec70a0215b732e264fe8
# 2   1           0              5acbbd4eb1538e45373b07f5
# 3   2           0              5acbbcda01235808d5d6dc75
# 4   1           0              5ab575fb6bdee65f759da8c1
# 5   2           0              5ab5575d73fe2516ad8f363b
# 6   1           0              5ab42db53c858d64af2688a4
# 7   3           0              5ab42c396f706a29f53ad1a8
# 8   6           0              5ab42b987dc9e17930e5ff5b
# 9   1           0              5ab42aca2a7ab6333652b266
# 10  1           0              5ab42a28da5e5617d18e3a6a
# 11  3           0              5ab429db1ffe971b060083f5
# 12  1           0              5ab3f53f8496ca57542d5549
# 13  1           0              5ab3f428da5e5617d17d1475
# 14  2           0              5ab3f3fedd70c572de886c9d

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Cowgirl
# {'address': '519 Hudson St', 'crossStreet': 'at W 10th St', 'lat': 40.73373338282062, 'lng': -74.0062998849649, 'labeledLatLngs': [{'label': 'display', 'lat': 40.73373338282062, 'lng': -74.0062998849649}], 'postalCode': '10014', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['519 Hudson St (at W 10th St)', 'New York, NY 10014', 'United States']}

# %% [markdown]
# ### Get User's friends

# %%
user_friends = pd.json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
user_data
# Out:
# {'id': '484542633',
#  'firstName': 'Nick',
#  'lastName': 'El-Tawil',
#  'gender': 'male',
#  'canonicalUrl': 'https://foursquare.com/user/484542633',
#  'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#   'suffix': '/484542633_unymNUmw_FdPs3GjXHujmHcYnN4hf8kEPADlOZuIrdcdm97VX3tFqL7fFNMNA_8Gl9NlU1GYg.jpg'},
#  'friends': {'count': 0,
#   'groups': [{'type': 'friends',
#     'name': 'Mutual friends',
#     'count': 0,
#     'items': []},
#    {'type': 'others', 'name': 'Other friends', 'count': 0, 'items': []}]},
#  'tips': {'count': 98},
#  'homeCity': 'New York, NY',
#  'bio': 'https://www.tawil.team/nick-el-tawil/',
#  'contact': {'twitter': 'nickeltawil'},
#  'photos': {'count': 2,
#   'items': [{'id': '5e41a7ce346b7c00085b0f70',
#     'createdAt': 1581361102,
#     'source': {'name': 'Foursquare for iOS',
#      'url': 'https://foursquare.com/download/#/iphone'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/484542633_cF12vc8JQJTd-hyznst-CsHHTdSoi4XwCGKhTuQXNfo.jpg',
#     'width': 1440,
#     'height': 1440,
#     'visibility': 'public',
#     'venue': {'id': '5ab194451ffed736e329b365',
#      'name': 'Tawil & Team',
#      'location': {'address': '413 W 14th St # 200',
#       'crossStreet': '9th Avenue',
#       'lat': 40.739614,
#       'lng': -74.005877,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 40.739614,
#         'lng': -74.005877}],
#       'postalCode': '10014',
#       'cc': 'US',
#       'city': 'New York',
#       'state': 'NY',
#       'country': 'United States',
#       'formattedAddress': ['413 W 14th St # 200 (9th Avenue)',
#        'New York, NY 10014',
#        'United States']},
#      'categories': [{'id': '5032885091d4c4b30a586d66',
#        'name': 'Real Estate Office',
#        'pluralName': 'Real Estate Offices',
#        'shortName': 'Real Estate',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#         'suffix': '.png'},
#        'primary': True}],
#      'like': False}}]},
#  'checkinPings': 'off',
#  'pings': False,
#  'type': 'user',
#  'mayorships': {'count': 0, 'items': []},
#  'checkins': {'count': 1, 'items': []},
#  'lists': {'count': 2,
#   'groups': [{'type': 'created', 'count': 0, 'items': []},
#    {'type': 'followed', 'count': 0, 'items': []},
#    {'type': 'yours',
#     'count': 2,
#     'items': [{'id': '484542633/todos',
#       'name': "Nick's Saved Places",
#       'description': '',
#       'type': 'todos',
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nickeltawil/list/todos',
#       'canonicalUrl': 'https://foursquare.com/nickeltawil/list/todos',
#       'listItems': {'count': 1}},
#      {'id': '484542633/venuelikes',
#       'name': 'Nick’s Liked Places',
#       'description': '',
#       'type': 'likes',
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nickeltawil/list/venuelikes',
#       'canonicalUrl': 'https://foursquare.com/nickeltawil/list/venuelikes',
#       'listItems': {'count': 0}}]}]},
#  'blockedStatus': 'none',
#  'lenses': []}

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=3LOX1XCTNAEPXKSWU1NEMIZB21FN4YVONAVZSSUFFQS2BR3K&client_secret=JIMJSWLBD5UVHYYVUX34PBRAFB51G22ADXPDBJYNYN2NBDC0&ll=40.715337,-74.008848&v=20180604&radius=5000&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '54148bc6498ea7bb8c05b70a',
#   'name': 'Juice Press',
#   'location': {'address': '83 Murray St',
#    'crossStreet': 'btwn Greenwich St & W Broadway',
#    'lat': 40.71478769908051,
#    'lng': -74.0111317502157,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71478769908051,
#      'lng': -74.0111317502157}],
#    'distance': 202,
#    'postalCode': '10007',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['83 Murray St (btwn Greenwich St & W Broadway)',
#     'New York, NY 10007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d3941735',
#     'name': 'Vegetarian / Vegan Restaurant',
#     'pluralName': 'Vegetarian / Vegan Restaurants',
#     'shortName': 'Vegetarian / Vegan',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-54148bc6498ea7bb8c05b70a-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = pd.json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                                                        name  \
# 0  Juice Press
# 1  Korin
# 2  Washington Market Park
# 3  Los Tacos No. 1
# 4  Four Seasons Hotel New York Downtown
# 5  The Class by Taryn Toomey
# 6  Aire Ancient Baths
# 7  One World Trade Center
# 8  9/11 Memorial North Pool
# 9  National September 11 Memorial & Museum (National September 11 Memorial)
#
#                       categories            address  \
# 0  Vegetarian / Vegan Restaurant  83 Murray St
# 1  Furniture / Home Store         57 Warren St
# 2  Playground                     Greenwich St
# 3  Taco Place                     136 Church St
# 4  Hotel                          27 Barclay St
# 5  Gym / Fitness Center           22 Park Pl
# 6  Spa                            88 Franklin St
# 7  Building                       1 World Trade Ctr
# 8  Memorial Site                  West St
# 9  Memorial Site                  180 Greenwich St
#
#                       crossStreet        lat        lng  \
# 0  btwn Greenwich St & W Broadway  40.714788 -74.011132
# 1  Church St                       40.714824 -74.009404
# 2  at Reade St                     40.717046 -74.011095
# 3  NaN                             40.714267 -74.008756
# 4  Broadway                        40.712612 -74.009380
# 5  NaN                             40.712753 -74.008734
# 6  at Church St                    40.718141 -74.004941
# 7  btwn Fulton & West St           40.713069 -74.013133
# 8  at Fulton St                    40.712077 -74.013187
# 9  btwn Liberty & Fulton St        40.711451 -74.013433
#
#                                                                                                                              labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71478769908051, 'lng': -74.0111317502157}]
# 1  [{'label': 'display', 'lat': 40.71482437714839, 'lng': -74.00940425461492}, {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}]
# 2  [{'label': 'display', 'lat': 40.71704598853704, 'lng': -74.01109457015991}]
# 3  [{'label': 'display', 'lat': 40.714267, 'lng': -74.008756}]
# 4  [{'label': 'display', 'lat': 40.71261246501983, 'lng': -74.00938032087628}]
# 5  [{'label': 'display', 'lat': 40.71275251771485, 'lng': -74.00873355601571}, {'label': 'entrance', 'lat': 40.712781, 'lng': -74.008548}]
# 6  [{'label': 'display', 'lat': 40.718141411641234, 'lng': -74.00494121234846}, {'label': 'entrance', 'lat': 40.718134, 'lng': -74.004846}]
# 7  [{'label': 'display', 'lat': 40.71306941116871, 'lng': -74.01313304901123}]
# 8  [{'label': 'display', 'lat': 40.71207726282092, 'lng': -74.01318669319153}]
# 9  [{'label': 'display', 'lat': 40.71145106322093, 'lng': -74.0134334564209}, {'label': 'entrance', 'lat': 40.711481, 'lng': -74.012691}]
#
#    distance postalCode  cc      city state        country  \
# 0  202       10007      US  New York  NY    United States
# 1  73        10007      US  New York  NY    United States
# 2  268       NaN        US  New York  NY    United States
# 3  119       10007      US  New York  NY    United States
# 4  306       10007      US  New York  NY    United States
# 5  287       10007      US  New York  NY    United States
# 6  453       10013      US  New York  NY    United States
# 7  440       10007      US  New York  NY    United States
# 8  515       NaN        US  New York  NY    United States
# 9  580       10006      US  New York  NY    United States
#
#                                                                      formattedAddress  \
# 0  [83 Murray St (btwn Greenwich St & W Broadway), New York, NY 10007, United States]
# 1  [57 Warren St (Church St), New York, NY 10007, United States]
# 2  [Greenwich St (at Reade St), New York, NY, United States]
# 3  [136 Church St, New York, NY 10007, United States]
# 4  [27 Barclay St (Broadway), New York, NY 10007, United States]
# 5  [22 Park Pl, New York, NY 10007, United States]
# 6  [88 Franklin St (at Church St), New York, NY 10013, United States]
# 7  [1 World Trade Ctr (btwn Fulton & West St), New York, NY 10007, United States]
# 8  [West St (at Fulton St), New York, NY, United States]
# 9  [180 Greenwich St (btwn Liberty & Fulton St), New York, NY 10006, United States]
#
#   neighborhood                        id
# 0  NaN          54148bc6498ea7bb8c05b70a
# 1  Tribeca      4af5d65ff964a52091fd21e3
# 2  NaN          4a9bcc2ff964a5203b3520e3
# 3  NaN          5d5f24ec09484500079aee00
# 4  NaN          57c640ad498e74977f98372f
# 5  NaN          58a253c830ecc66c9e5b40a0
# 6  NaN          4fbbd9ede4b0756c0d4c2364
# 7  NaN          4abe7f9ef964a520068e20e3
# 8  NaN          58801864cc5b6a14dedce689
# 9  NaN          4b6b5abff964a520fb022ce3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='Yellow',
    fill_opacity=0.6 
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label.replace("'",""),
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec745c3ad1ab4001b3b3dca'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %% [markdown]
# <a id="item6"></a>
